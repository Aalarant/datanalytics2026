# %% [markdown]
# ### First exercise

# %%
from sklearn.preprocessing import LabelEncoder

variables = ['Stock_Market']

encoder = LabelEncoder()
df[variables] = df[variables].apply(encoder.fit_transform)

# %%
print("Hello World")

# %% [markdown]
# Value count counts the amounts of the data.

# %%
df['Size'].value_counts()


# Map the numeric values to each option
category_mapper = {
    0: 'Small',
    1: 'Medium',
    2: 'Large'
}

# Convert each value into numeric version using the mapping above.
# Also this is the easiest way.
# Can only be used if the categories have some kind of an order of magnitude.
df['Size'] = df['Size'].map(category_mapper)

# %% [markdown]
# ### Normal categories:

# %%
df['Area'].value_counts()

# %% [markdown]
# ### Nominal categories

# %% [markdown]
# Nominal categories are usually beginner's trap. Don't treat nominal categories as if they were ordinal categories!
