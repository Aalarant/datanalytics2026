# %% [markdown]
# <h3><b>Data Analytics - Exercise set 2 - pandas-module</b></h3>

# %% [markdown]
# Put all your exercises (in Jupyter Notebook(s) ) in your course Git-project.<br /><br />
# <span style="font-weight: bold;">Use either code comments or Jupyter Notebook markdown (text) to document which exercise you are doing and what a certain code section does!</span><br />
#
# <span style="font-weight: bold;">Remember: your Jupyter notebook's clarity (how easy it is to read and understand) also affects your scoring!</span><br /><br />

# %% [markdown]
# <span style="font-weight: bold;">Remember also:
# <span style="font-weight: bold;">If you use generative AI in any part of any exercise,
# MENTION IT CLEARLY! </span><br />

# %% [markdown]
# **Regarding all exercises in this exercise set:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="font-weight: bold;">(code comments are enough, also mention the prompts used).</span><br /><br />
# See also the materials discussing the usage of AI in this course!</span><br /><br />
#
#
# You can return all of these exercises in a single Jupyter Notebook, if you wish.

# %% [markdown]
# <hr>

# %% [markdown]
# <b>The datasets for these exercises have been collected from kaggle.com<br />
# (a service providing different datasets for practice)</b>
#
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_2/es2_1.png" />
#
# **Some details in these datasets have been modified by instructor for a better learning experience.**

# %% [markdown]
# ### Recommended setup, switching to decimal format:

# %%
# basic imports
import numpy as np
import pandas as pd

# recommended, switch to decimal format so that pandas doesn't 
# use scientific notation for large values by default
np.set_printoptions(suppress=True)
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# <h4><b>1. import pandas and read the csv-file found in Moodle (loans.csv). Use Python coding with pandas to answer the questions.</b></h4>

# %% [markdown]
# Have also the data files for all exercises in your Git!

# %%
# load the needed csv-file with pandas
# NOTE! have also the data files in your Git!

# %% [markdown]
# <li>Print the head of the data (df.head() )</li>

# %%
# print out the head of the DataFrame

# %% [markdown]
# <ul>
#     <li>Remove (filter out) loans  <b style="color: red;">that are unrealistically large</b> (Current Loan Amount should be less than 99999999)</li>
#     <ul>
#         <li><b>Tip:</b> use conditional filtering!</li>
#     </ul>
# </ul>

# %%
# remove loans that are too large

# %% [markdown]
# <ul>
# <li>Which loan(s) have the highest <b><i>Current Credit Balance</i></b>?</li>
#     <ul>
#         <li><b>Recommended:</b> use <b>nlargest()</b></li>
#     </ul>
# </ul>

# %%
# study which loans have the highest Current Credit Balance here

# %% [markdown]
# <ul>
# <li>Which loan(s) have the smallest <b><i>Annual Income</i></b>?</li>
#     <ul>
#         <li><b>Recommended:</b> use <b>nsmallest()</b></li>
#     </ul>
# </ul>

# %%
# study which loans have the smallest Annual Income here

# %% [markdown]
# <ul>
# <li>Use <b>describe()</b>, and answer the following questions
# in your notebook: </li>
#     <ul>
#         <li>What is the <b>min, max and mean</b> of <b><i>Current Loan Amount</i></b>?</li>
#         <li>In which values the <b>quantiles</b> are located in <b><i>Current Loan Amount</i></b>? (25%, 50%, 75%)</li>
#     </ul>
# </ul>

# %%
# use describe() and study the needed values

# %% [markdown]
# <li>Create a new field into your dataset called <b>Actual Annual Income</b>.</li>
# <br><b>Note:</b> The Actual Annual Income follows this formula:<br>
# <b style="color: green">Annual Income – 12 * Monthly Debt</b><br>

# %%
# create a new field for Actual Annual income (annual income - 12 * monthly debt)

# %% [markdown]
# - How many loans are "Long term"?
#     - (tip: use value_counts() )

# %%
# produce code that shows many loans are long term

# %% [markdown]
# <li>What are the 3 most common loan purposes? (tip: use value_counts() )</li>

# %% [markdown]
# - <b>Small extra task:</b> There seems to be two versions of "other" in the data for loan purpose.
#
#     - <b>Replace "other" with "Other" to unite these categories.</b>
#
# - <b>Small extra task:</b>  study the distribution of "Number of Credit Problems" by using value_counts(). Explain your findings.

# %%
# find the 3 most common loan purposes here

# %% [markdown]
# - How many unique <b>Home Ownership</b> -options there are in the dataset?
#     - (tip: unique() or value_counts() )

# %%
# find out the unique home ownerships here

# %% [markdown]
# <hr>

# %% [markdown]
# ### Other small extra tasks:

# %% [markdown]
# <li>How many loaners have more than 1 bankruptcy?</li>

# %%
# produce code that shows how many loaners have more than 1 bankruptcy

# %% [markdown]
# <li>How many Short Term loans are for Home Improvements?</li>
#     - <b>Easiest way:</b> first, conditional filter by short term loans
# => then use value_counts() for Purpose

# %%
# produce code that shows how many of the Short Term loans are for Home Improvements

# %% [markdown]
# <li>Is there a correlation between <b>Annual Income</b> and <b>Number of Open Accounts</b> or is there a correlation between <b>Number of Credit Problems</b> and <b>Bankruptcies</b>?</li>
# <br />
# <b>EXPLAIN AND DISCUSS YOUR FINDINGS AS WELL! (code comments or markdown)</b>

# %%
# produce code that shows which correlation statement is true

# %% [markdown]
# <hr>

# %% [markdown]
# <h4><b>2. Download the purchases.csv from Moodle, and do the following observations and tasks:</b></h4>

# %% [markdown]
# <li>What was the total price sum of the Purchase Order Number 018H2015? (14 rows in total)</li>
#     - Tip: use conditional filtering!

# %%
# produce the code that gets the needed total price sum

# %% [markdown]
# <li>What is the name and description of the purchased item with the Purchase Order Number 3176273?</li>

# %%
# produce the code that gets the needed name and description

# %% [markdown]
# <li>How many occasions (rows) of purchase data happened during the year 2013?</li>

# %%
# produce the code that filters the needed data for year 2013

# %% [markdown]
# <ul><li>What are the 5 most common Departments in the data?</li> (Tip: value_counts() !)
# <br><br>
# <ul><li><b>Extra task: </b>What are 3 Departments using most money in the data?</li> (Tips: groupby(), sum(), sort_values()!</ul>
# </ul>

# %%
# produce the code that gets the needed most common departments

# %% [markdown]
# <li>Replace the $-sign of the Unit Price –column with an empty string, and convert the value to float</li>

# %%
# replace the $-sign of the Unit Price column and convert the value to float here

# %% [markdown]
# <ul>
# <li><b>Small extra tasks for extra points</b></li>
# <ul>
# <li>How many purchases in the data were IT Goods and had the total price more than 50000 dollars?</li>
# <li>How many of the purchases have anything to do with IT? (IT Goods, IT Services, IT Telecommunications)</li>
#
# </ul>
# </ul>

# %%
# produce the code for the extra tasks if you wish complete them

# %% [markdown]
# <ul>
# <li><b>Other extra tasks for extra points</b></li>
# <ul>
# <li>Filter out purchases that have a Total Price of 0 or less</li>
# <li>After this, use groupby() –function twice (separately) to group the purchases data by Acquisition Type, and then calculating the result first by sum() and then by mean()</li>
# <li><b>In other words:</b> get the sum and mean of total price by acquisition type</li>
# <li>Which two acquisition types have the largest sums and means after grouping the data?</li>
# </ul>
# </ul>

# %%
# produce the code for the extra tasks if you wish to complete them

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_2/es2_2.png" />

# %% [markdown]
# <hr>

# %% [markdown]
# <h4><b>3. Download the salaries_india.csv from Moodle, and consider the following questions of the data. Use any means in pandas (or even NumPy) you wish to explain your answers.</b></h4>

# %% [markdown]
# <b>Note:</b> the salaries are in Indian rupees (currency)

# %% [markdown]
# - <b>Remove the columns "Row ID" and "Job Title"</b>
#
#     - (Tip: use df.drop() !)

# %%
# remove the two columns (Tip: use df.drop() !)

# %% [markdown]
# - **How large are the highest salaries in this dataset?**
#     - Decide which high salaries can be considered as outliers (values too far away from the main distribution)
#         - **Tip:** **df['Salary'].hist()** can be useful here to decide a good cut-off point!
#         - Remember also nlargest() and value_counts()!
#
#     - After this, remove all salaries that are too high in your opinion (remove the outliers)
#         - Conditional filtering is the easiest approach here!

# %%
# produce the code needed to study the highest salary in the dataset

# %% [markdown]
# - **This dataset has categorical variables, process them as required:**
#
#     - Handle "Employment Status" as a binary variable (LabelEncoder)
#     - Handle "Rating" as an ordinal variable (use category mapping)
#     - Handle "Job Roles" and "Location" as NOMINAL categories (OneHotEncoder)

# %%
# produce the code that handles the categories correctly

# %% [markdown]
# - **Finally, create a correlation matrix of the dataset:**
#     - Analyze the correlation matrix from the point of view of Salary
#
#         - Which variables have the biggest impact on a salary?
#             - You can also discuss for the potential reasons behind these trends
#
#         - Try also experimenting with the outlier cutoff point, does it affect the correlations if you cut more high salaries out of the data in the earlier phase?
#
# <br>
#
# - **Small extra task:** You can also try the Spearman correlation for a slightly different result:
#     - df.corr(method="spearman", numeric_only=True)

# %%
# examples for handling different categorical variables can be found in Moodle
# also check the pandas -materials on how to convert different types of categories correctly

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <hr>

# %% [markdown]
# <b>Advanced extra tasks for this dataset</b><br><br>
#
# <ul>
# <li>After all salaries have been converted to correct format by using the helper function (check Moodle), use quantiles and split the data into four different parts, based on salary:</li>
# <ul>
# <li><span style="color: red;">Top 25%</span><br>=> quantile(0.75)</li>
# <li><span style="color: red;">Above average, values between top 25-50%</span><br>
# => quantile(0.5)  - quantile(0.75)</li>
# <li><span style="color: red;">Below average, values between top 50-75% </span><br>
# => quantile(0.25) – quantile(0.5)
# </li>
# <li><span style="color: red;">Bottom 25%</span><br>=> quantile(0.25)</li>
# <br>
# <li>What are the salary ranges for each quantile?</li>
# <li>Do the correlations change after splitting the dataset?</li>
# <li>See examples in pandas-materials on how to use quantiles</li>
# </li>
# </ul>
# </ul>
# <hr>
#
# <ul>
# <li>Did you get any ideas how this data could be improved?</li>
# <li>Do we need some particular new data or some other operations on the data?</li>
# <li>Should we filter something out based on some other column?<br><br><b>Provide arguments for your answers in code comments.</b><br><br> </li>
# <ul>
# <li>Note: There are many good possible answers here!</li>
# <li>Tip: How about replacing the "Salaries Reported" column with actual rows based on that number? Try doing this with the data!</li>
# <li>Remember: This data only represents data engineering salaries based on selected Indian cities.
# The world is a vast place :)
# </li>
# </ul>
# </ul>

# %%
# code for the extra tasks

# %% [markdown]
# <hr>

# %% [markdown]
# - **4. Download the furnitures.csv from Moodle, and perform the following tasks with it:**
#
#     - Inspect how many duplicate values / rows there are in the dataset
#         - After this, remove the duplicated rows from the dataset

# %%
# inspect the duplicate rows here + remove the duplicated rows from the dataset afterwards

# %% [markdown]
# - **Inspect how many NaN –values the dataset has.**
# 	- After this, remove all NaN –values from the dataset

# %%
# inspect the NaN -values here + remove them from the dataset afterwards

# %% [markdown]
# - **Extra task ideas for handling NaN-values:**
#
#     - Instead of just removing NaN-rows, try imputation / smart replacement:
#
#         - **Version 1:** Use overall mean price to replace the missing value
#
#         - **Version 2:** Use typical mean prices for different materials/categories and/or brands in the dataset (more points)
#
#         - **Version 3:** Calculate a typical profit multiplier for each type of product (price / cost) and deduce the price from the product cost after this (more points)

# %%
# code for the above extra tasks if needed

# %% [markdown]
# - Create a new column: **delivery_category**
#
# - Use this logic in the creation of this column:
#     - If delivery days are less than 4 => category is "quick"
#     - If delivery days are 4 – 7 => category is "normal"
#     - If delivery days are over 7 => category is "slow"
#
# - Easiest way to do this is to create a helper function and use df.apply()
#     - See the age group –example in the lecture Git housing analysis notebook!

# %%
# create the helper function for delivery category here
# and also use it via apply() to modify the dataset

# %% [markdown]
# - **After this, use value_counts() and inspect the distribution of the delivery category**
#     - Study also the data itself by using df.head()

# %%
# use value_counts(), head()

# %% [markdown]
# - **Finally, remove the original delivery_days –column from the dataset**

# %%
# finally remove the original column from the dataset

# %% [markdown]
# - **Extra tasks:**
#
#     - Use the discount_percentage- and price-columns to calculate the actual amount of discount (money), and round the result to two decimals
#         - After this operation, remove the original discount_percentage –variable!
#
#     - Handle all the categories properly in the dataset, and study the dataset: **which factors affect the selling price the most?**
#
#         - Summary DataFrames with groupby() can be helpful here too!

# %%
# code for the extra tasks above

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <hr>

# %% [markdown]
# <h2><b>Advanced extra tasks for extra points (varying challenges, some require Googling):</b></h2>

# %% [markdown]
# <ul>
# <li><b>1. Data merge is a useful tool when you have multiple files of data that have the exact same structure.</b><br><br>Download the two csv-files from Moodle (videogames1.csv, videogames2.csv), and combine them into one DataFrame. <br><br>Lastly, save the Data Frame into a new csv-file => combined.csv.</li>
# </ul>

# %%
# code for the advanced extra task

# %% [markdown]
# - **2. Try using phik-matrix with the salaries_india.csv –dataset. Are the association matrix results any different from the correlation matrix?**
#     - Note: you need to install phik_matrix first:
#
#         - pip install phik
#
#     - After this you can use phik-matrix for your DataFrame:
#
#         - df.phik_matrix()
#
#     - Phik-matrix measures association (non-linear connection) between variables.
#
#     - This is extremely helpful in situations where correlations can't tell the whole story of the dataset.

# %%
# code for the advanced extra task

# %% [markdown]
# <ul>
# <li><b>3.	Normalization allows us to convert the values of numeric columns to be between 0 and 1.</b>
#
# This is helpful when two different numbers seem to follow the same trend, but have completely different value ranges. For example, gold and silver prices tend to follow similar patterns, but their market worth is quite different. By using normalization, we can compare these trends more easily. <br>
#
# Get historical prices of both gold and silver, and compare them without and with normalization. You can plot the prices by using df.plot() –function. Check the dataset in list in Moodle for some alternatives for gold and silver prices.
# </li>
# </ul>
# <br>
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_2/es2_4.png" />

# %%
# this exercise preferably to its separate Jupyter notebook!
